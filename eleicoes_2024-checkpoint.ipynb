# %%
import pandas as pd

# %%
df=pd.read_csv('quantitativo_municipios-municipio_2024.csv',encoding='latin1',sep=';')
df.head()
# Out:
#   nm_pais nm_regiao sg_uf  nm_municipio  qt_municipio  qt_municipio_brasil  \
# 0  Brasil     NORTE    AC    ACRELÂNDIA             1                    1
# 1  Brasil     NORTE    AC  ASSIS BRASIL             1                    1
# 2  Brasil     NORTE    AC     BRASILÉIA             1                    1
# 3  Brasil     NORTE    AC        BUJARI             1                    1
# 4  Brasil     NORTE    AC      CAPIXABA             1                    1
#
#    qt_municipio_exterior  qt_municipio_sem_biometria  qt_municipio_biometria  \
# 0                      0                           0                       1
# 1                      0                           0                       1
# 2                      0                           0                       1
# 3                      0                           0                       1
# 4                      0                           0                       1
#
#    qt_municipio_hibrido
# 0                     0
# ...

# %%
df.tail()
# Out:
#      nm_pais nm_regiao sg_uf  nm_municipio  qt_municipio  qt_municipio_brasil  \
# 5564  Brasil     NORTE    TO    TOCANTÍNIA             1                    1
# 5565  Brasil     NORTE    TO      TUPIRAMA             1                    1
# 5566  Brasil     NORTE    TO    TUPIRATINS             1                    1
# 5567  Brasil     NORTE    TO  WANDERLÂNDIA             1                    1
# 5568  Brasil     NORTE    TO       XAMBIOÁ             1                    1
#
#       qt_municipio_exterior  qt_municipio_sem_biometria  \
# 5564                      0                           0
# 5565                      0                           0
# 5566                      0                           0
# 5567                      0                           0
# 5568                      0                           0
#
#       qt_municipio_biometria  qt_municipio_hibrido
# 5564                       1                     0
# 5565                       1                     0
# ...

# %%
df.shape
# Out:
# (5569, 10)

# %%
df.describe()
# Out:
#        qt_municipio  qt_municipio_brasil  qt_municipio_exterior  \
# count        5569.0               5569.0                 5569.0
# mean            1.0                  1.0                    0.0
# std             0.0                  0.0                    0.0
# min             1.0                  1.0                    0.0
# 25%             1.0                  1.0                    0.0
# 50%             1.0                  1.0                    0.0
# 75%             1.0                  1.0                    0.0
# max             1.0                  1.0                    0.0
#
#        qt_municipio_sem_biometria  qt_municipio_biometria  \
# count                      5569.0             5569.000000
# mean                          0.0                0.809481
# std                           0.0                0.392746
# min                           0.0                0.000000
# 25%                           0.0                1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5569 entries, 0 to 5568
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   nm_pais                     5569 non-null   object
#  1   nm_regiao                   5569 non-null   object
#  2   sg_uf                       5569 non-null   object
#  3   nm_municipio                5569 non-null   object
#  4   qt_municipio                5569 non-null   int64
#  5   qt_municipio_brasil         5569 non-null   int64
#  6   qt_municipio_exterior       5569 non-null   int64
#  7   qt_municipio_sem_biometria  5569 non-null   int64
#  8   qt_municipio_biometria      5569 non-null   int64
#  9   qt_municipio_hibrido        5569 non-null   int64
# dtypes: int64(6), object(4)
# memory usage: 435.2+ KB

# %%
df['nm_regiao'].value_counts()
# Out:
# NORDESTE        1793
# SUDESTE         1668
# SUL             1191
# CENTRO-OESTE     467
# NORTE            450
# Name: nm_regiao, dtype: int64

# %%
df['sg_uf'].value_counts()
# Out:
# MG    853
# SP    645
# RS    497
# BA    417
# PR    399
# SC    295
# GO    246
# PI    224
# PB    223
# MA    217
# CE    184
# PE    184
# RN    167
# PA    144
# MT    142
# TO    139
# AL    102
# RJ     92
# MS     79
# ES     78
# SE     75
# AM     62
# RO     52
# AC     22
# AP     16
# RR     15
# Name: sg_uf, dtype: int64

# %%
df=pd.read_csv('bweb_2t_SP_281020241046.csv',encoding='latin1',sep=';')
df.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  28/10/2024   10:46:41         2024                0  Eleição Ordinária
# 1  28/10/2024   10:46:41         2024                0  Eleição Ordinária
# 2  28/10/2024   10:46:41         2024                0  Eleição Ordinária
# 3  28/10/2024   10:46:41         2024                0  Eleição Ordinária
# 4  28/10/2024   10:46:41         2024                0  Eleição Ordinária
#
#    CD_PLEITO            DT_PLEITO  NR_TURNO  CD_ELEICAO  \
# 0        453  2024-10-27 00:00:00         2         620
# 1        453  2024-10-27 00:00:00         2         620
# 2        453  2024-10-27 00:00:00         2         620
# 3        453  2024-10-27 00:00:00         2         620
# 4        453  2024-10-27 00:00:00         2         620
#
#                  DS_ELEICAO  ... CD_FLASHCARD_URNA_EFETIVADA  \
# 0  Eleições Municipais 2024  ...                    1CBE5FE2
# ...

# %%
df.tail()
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 179569  28/10/2024   10:46:41         2024                0
# 179570  28/10/2024   10:46:41         2024                0
# 179571  28/10/2024   10:46:41         2024                0
# 179572  28/10/2024   10:46:41         2024                0
# 179573  28/10/2024   10:46:41         2024                0
#
#           NM_TIPO_ELEICAO  CD_PLEITO            DT_PLEITO  NR_TURNO  \
# 179569  Eleição Ordinária        453  2024-10-27 00:00:00         2
# 179570  Eleição Ordinária        453  2024-10-27 00:00:00         2
# 179571  Eleição Ordinária        453  2024-10-27 00:00:00         2
# 179572  Eleição Ordinária        453  2024-10-27 00:00:00         2
# 179573  Eleição Ordinária        453  2024-10-27 00:00:00         2
#
#         CD_ELEICAO                DS_ELEICAO  ... CD_FLASHCARD_URNA_EFETIVADA  \
# 179569         620  Eleições Municipais 2024  ...                    C6EAE698
# ...

# %%
df=pd.read_csv('consulta_cand_2024_SP.csv',encoding='latin1',sep=';')
df.head().T
# Out:
#                                                              0  \
# DT_GERACAO                                          14/10/2025
# HH_GERACAO                                            08:30:10
# ANO_ELEICAO                                               2024
# CD_TIPO_ELEICAO                                              1
# NM_TIPO_ELEICAO                            ELEIÇÃO SUPLEMENTAR
# NR_TURNO                                                     1
# CD_ELEICAO                                                6160
# DS_ELEICAO                     Eleição Suplementar de Panorama
# DT_ELEICAO                                          08/06/2025
# TP_ABRANGENCIA                                       MUNICIPAL
# SG_UF                                                       SP
# SG_UE                                                    68098
# NM_UE                                                 PANORAMA
# CD_CARGO                                                    11
# ...

# %%
df.tail().T
# Out:
#                                                                            78396  \
# DT_GERACAO                                                            14/10/2025
# HH_GERACAO                                                              08:30:10
# ANO_ELEICAO                                                                 2024
# CD_TIPO_ELEICAO                                                                2
# NM_TIPO_ELEICAO                                                ELEIÇÃO ORDINÁRIA
# NR_TURNO                                                                       1
# CD_ELEICAO                                                                   619
# DS_ELEICAO                                              Eleições Municipais 2024
# DT_ELEICAO                                                            06/10/2024
# TP_ABRANGENCIA                                                         MUNICIPAL
# SG_UF                                                                         SP
# ...

# %%
df.describe()
# Out:
#        ANO_ELEICAO  CD_TIPO_ELEICAO      NR_TURNO    CD_ELEICAO         SG_UE  \
# count      78401.0     78401.000000  78401.000000  78401.000000  78401.000000
# mean        2024.0         1.999490      1.000918    621.822643  66490.901978
# std            0.0         0.022582      0.030291    124.904830   3482.819257
# min         2024.0         1.000000      1.000000    619.000000  61000.000000
# 25%         2024.0         2.000000      1.000000    619.000000  63231.000000
# 50%         2024.0         2.000000      1.000000    619.000000  66290.000000
# 75%         2024.0         2.000000      1.000000    619.000000  69671.000000
# max         2024.0         2.000000      2.000000   6238.000000  72737.000000
#
#            CD_CARGO  SQ_CANDIDATO  NR_CANDIDATO  NR_CPF_CANDIDATO  \
# count  78401.000000  7.840100e+04  78401.000000           78401.0
# mean      12.916838  2.500021e+11  29646.566817              -4.0
# std        0.362527  1.489952e+05  19860.678821               0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78401 entries, 0 to 78400
# Data columns (total 50 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DT_GERACAO                     78401 non-null  object
#  1   HH_GERACAO                     78401 non-null  object
#  2   ANO_ELEICAO                    78401 non-null  int64
#  3   CD_TIPO_ELEICAO                78401 non-null  int64
#  4   NM_TIPO_ELEICAO                78401 non-null  object
#  5   NR_TURNO                       78401 non-null  int64
#  6   CD_ELEICAO                     78401 non-null  int64
#  7   DS_ELEICAO                     78401 non-null  object
#  8   DT_ELEICAO                     78401 non-null  object
#  9   TP_ABRANGENCIA                 78401 non-null  object
#  10  SG_UF                          78401 non-null  object
#  11  SG_UE                          78401 non-null  int64
# ...

# %%
df['NM_PARTIDO'].value_counts()
# Out:
# PARTIDO SOCIAL DEMOCRÁTICO                        7122
# PARTIDO LIBERAL                                   6828
# REPUBLICANOS                                      6771
# MOVIMENTO DEMOCRÁTICO BRASILEIRO                  6250
# UNIÃO BRASIL                                      5749
# PODEMOS                                           5555
# PROGRESSISTAS                                     5302
# PARTIDO SOCIALISTA BRASILEIRO                     4477
# PARTIDO DOS TRABALHADORES                         3438
# PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA           3424
# PARTIDO RENOVAÇÃO DEMOCRÁTICA                     3403
# SOLIDARIEDADE                                     3057
# AVANTE                                            2954
# PARTIDO DEMOCRÁTICO TRABALHISTA                   2883
# DEMOCRACIA CRISTÃ                                 1566
# PARTIDO NOVO                                      1460
# AGIR                                              1367
# ...

# %%
df.nlargest(5,'CD_OCUPACAO')
# Out:
#     DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO      NM_TIPO_ELEICAO  \
# 4   14/10/2025   08:30:10         2024                1  ELEIÇÃO SUPLEMENTAR
# 5   14/10/2025   08:30:10         2024                2    ELEIÇÃO ORDINÁRIA
# 8   14/10/2025   08:30:10         2024                2    ELEIÇÃO ORDINÁRIA
# 9   14/10/2025   08:30:10         2024                2    ELEIÇÃO ORDINÁRIA
# 29  14/10/2025   08:30:10         2024                2    ELEIÇÃO ORDINÁRIA
#
#     NR_TURNO  CD_ELEICAO                             DS_ELEICAO  DT_ELEICAO  \
# 4          1        6238  Eleição Suplementar de Sales Oliveira  14/09/2025
# 5          1         619               Eleições Municipais 2024  06/10/2024
# 8          1         619               Eleições Municipais 2024  06/10/2024
# 9          1         619               Eleições Municipais 2024  06/10/2024
# 29         1         619               Eleições Municipais 2024  06/10/2024
#
# ...

# %%
df['DS_COR_RACA'].value_counts()
# Out:
# BRANCA            51629
# PARDA             18189
# PRETA              7676
# NÃO INFORMADO       489
# AMARELA             331
# INDÍGENA             86
# NÃO DIVULGÁVEL        1
# Name: DS_COR_RACA, dtype: int64

# %%
df['DS_OCUPACAO'].value_counts()
# Out:
# OUTROS                                  19390
# EMPRESÁRIO                               6788
# SERVIDOR PÚBLICO MUNICIPAL               5956
# COMERCIANTE                              4016
# APOSENTADO (EXCETO SERVIDOR PÚBLICO)     3996
#                                         ...
# JOALHEIRO E OURIVES                         1
# BACTERIOLOGISTA E ASSEMELHADOS              1
# PETROLEIRO                                  1
# DETETIVE PARTICULAR                         1
# MAGISTRADO                                  1
# Name: DS_OCUPACAO, Length: 241, dtype: int64

# %%
df['DS_GRAU_INSTRUCAO'].value_counts()
# Out:
# ENSINO MÉDIO COMPLETO            31020
# SUPERIOR COMPLETO                25574
# ENSINO FUNDAMENTAL COMPLETO       7957
# ENSINO FUNDAMENTAL INCOMPLETO     5526
# SUPERIOR INCOMPLETO               3714
# ENSINO MÉDIO INCOMPLETO           3184
# LÊ E ESCREVE                      1425
# NÃO DIVULGÁVEL                       1
# Name: DS_GRAU_INSTRUCAO, dtype: int64

# %%
df['DS_GENERO'].value_counts()
# Out:
# MASCULINO         51587
# FEMININO          26813
# NÃO DIVULGÁVEL        1
# Name: DS_GENERO, dtype: int64

# %%
 df['SG_UF'].value_counts()
# Out:
# SP    78401
# Name: SG_UF, dtype: int64

# %%
df['DS_CARGO'].value_counts()
# Out:
# VEREADOR         74044
# VICE-PREFEITO     2194
# PREFEITO          2163
# Name: DS_CARGO, dtype: int64

# %%
df['SG_PARTIDO'].value_counts()
# Out:
# PSD              7122
# PL               6828
# REPUBLICANOS     6771
# MDB              6250
# UNIÃO            5749
# PODE             5555
# PP               5302
# PSB              4477
# PT               3438
# PSDB             3424
# PRD              3404
# SOLIDARIEDADE    3057
# AVANTE           2954
# PDT              2883
# DC               1566
# NOVO             1460
# AGIR             1367
# MOBILIZA         1279
# PRTB             1207
# PSOL              957
# CIDADANIA         879
# PMB               844
# PV                672
# REDE              645
# PC do B           201
# PCO                53
# PSTU               31
# UP                 14
# PCB                12
# Name: SG_PARTIDO, dtype: int64

# %%
df['SG_PARTIDO'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['SG_PARTIDO'].value_counts().head(7).plot.pie(
    autopct='%1.1f%%', figsize=(7,7), ylabel='', title='Top 7 Ocupações'
)
# Out:
# <AxesSubplot:title={'center':'Top 7 Ocupações'}>

# %%
df['DS_SIT_TOT_TURNO'].value_counts()
# Out:
# SUPLENTE            37653
# NÃO ELEITO          30148
# ELEITO POR QP        4240
# ELEITO POR MÉDIA     2807
# #NULO                2197
# ELEITO               1284
# 2º TURNO               72
# Name: DS_SIT_TOT_TURNO, dtype: int64
