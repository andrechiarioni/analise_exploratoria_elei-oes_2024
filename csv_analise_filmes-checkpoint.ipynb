# %%
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv('lancamentos-comerciais-por-distribuidoras.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df=pd.read_csv('lancamentos-comerciais-por-distribuidoras.csv')
#
# File ~\anaconda3.9\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
print(os.listdir())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 print(os.listdir())
#
# NameError: name 'os' is not defined

# %%
df=pd.read_excel('df=pd.read_csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 df=pd.read_excel('df=pd.read_csv')
#
# File ~\anaconda3.9\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 os.getcwd()
#
# NameError: name 'os' is not defined

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\vitor\Documentos\curso lab hacker

# %%
df=pd.read_csv('Credit.csv')

# %%
df.shape
# Out:
# (1000, 21)

# %%
df.describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
df.head()
df.tail()
# Out:
#     checking_status  duration                    credit_history  \
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount savings_status  employment  \
# 995  furniture/equipment           1736           <100      4<=X<7
# 996           'used car'           3857           <100      1<=X<4
# 997             radio/tv            804           <100         >=7
# 998             radio/tv           1845           <100      1<=X<4
# 999           'used car'           4576     100<=X<500  unemployed
#
#      installment_commitment       personal_status other_parties  ...  \
# 995                       3  'female div/dep/mar'          none  ...
# ...

# %%
df.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
df2 = pd.read_csv('lancamentos-comerciais-por-distribuidoras.csv', sep=';')

# %%
df2.head()
# Out:
#   DATA_LANCAMENTO_OBRA  TITULO_ORIGINAL         CPB_ROE TIPO_OBRA  \
# 0           28/08/2025        AFTERBURN  E2500252400000    FICÇÃO
# 1           28/08/2025  CAUGHT STEALING  E2500247500000    FICÇÃO
# 2           28/08/2025    O ÚLTIMO AZUL  B2500299400000    FICÇÃO
# 3           28/08/2025        THE ROSES  E2500319600000    FICÇÃO
# 4           21/08/2025   BRING HER BACK  E2500097000000    FICÇÃO
#
#         PAIS_OBRA  PUBLICO_TOTAL      RENDA_TOTAL  \
# 0  ESTADOS UNIDOS          46053    R$ 470.924,38
# 1  ESTADOS UNIDOS         107990  R$ 1.252.810,34
# 2          BRASIL          46977    R$ 572.655,04
# 3  ESTADOS UNIDOS         101626  R$ 1.277.572,66
# 4  ESTADOS UNIDOS         277417  R$ 4.051.978,80
#
#                           RAZAO_SOCIAL_DISTRIBUIDORA  REGISTRO_DISTRIBUIDORA  \
# 0  DIAMOND FILMS DO BRASIL PRODUÇÃO E DISTRIBUIÇÃ...                 22724.0
# 1             COLUMBIA TRISTAR FILMES DO BRASIL LTDA                    84.0
# ...

# %%
df2.tail()
# Out:
#      DATA_LANCAMENTO_OBRA     TITULO_ORIGINAL         CPB_ROE TIPO_OBRA  \
# 6710           04/01/2009       THE STRANGERS  E1600633000000    FICÇÃO
# 6711           02/01/2009  SE EU FOSSE VOCÊ 2  B0800958700000    FICÇÃO
# 6712           02/01/2009  SE EU FOSSE VOCÊ 2  B0800958700000    FICÇÃO
# 6713           01/01/2009                BOLT  E1500346000000  ANIMAÇÃO
# 6714           01/01/2009   LA BELLE PERSONNE  E1600594000000    FICÇÃO
#
#            PAIS_OBRA  PUBLICO_TOTAL       RENDA_TOTAL  \
# 6710  ESTADOS UNIDOS         291713   R$ 2.350.017,91
# 6711          BRASIL          29830      R$ 37.557,00
# 6712          BRASIL        6113251  R$ 50.545.885,00
# 6713  ESTADOS UNIDOS        1162616   R$ 9.590.392,25
# 6714          FRANÇA          17207     R$ 141.070,93
#
#                      RAZAO_SOCIAL_DISTRIBUIDORA  REGISTRO_DISTRIBUIDORA  \
# 6710            SM DISTRIBUIDORA DE FILMES LTDA                 11922.0
# ...

# %%
df2.shape
# Out:
# (6715, 10)

# %%
df2.describe()
# Out:
#        PUBLICO_TOTAL  REGISTRO_DISTRIBUIDORA
# count   6.715000e+03             6714.000000
# mean    3.338704e+05            10397.543938
# std     1.151062e+06            12530.983631
# min     1.000000e+00                6.000000
# 25%     1.641000e+03              265.000000
# 50%     1.099500e+04             4904.000000
# 75%     1.067410e+05            17484.000000
# max     2.247195e+07            60300.000000

# %%
df2.head(20)
# Out:
#    DATA_LANCAMENTO_OBRA                                    TITULO_ORIGINAL  \
# 0            28/08/2025                                          AFTERBURN
# 1            28/08/2025                                    CAUGHT STEALING
# 2            28/08/2025                                      O ÚLTIMO AZUL
# 3            28/08/2025                                          THE ROSES
# 4            21/08/2025                                     BRING HER BACK
# 5            21/08/2025           C.I.C - CENTRAL DE INTELIGÊNCIA CEARENSE
# 6            21/08/2025                        LUIZ GONZAGA - LEGUA TIRANA
# 7            21/08/2025              MOACYR LUZ, O EMBAIXADOR DESSA CIDADE
# 8            21/08/2025                                           NOBODY 2
# 9            21/08/2025                                              RABIA
# 10           21/08/2025                                        SPLITSVILLE
# ...

# %%
df2.dtypes
# Out:
# DATA_LANCAMENTO_OBRA           object
# TITULO_ORIGINAL                object
# CPB_ROE                        object
# TIPO_OBRA                      object
# PAIS_OBRA                      object
# PUBLICO_TOTAL                   int64
# RENDA_TOTAL                    object
# RAZAO_SOCIAL_DISTRIBUIDORA     object
# REGISTRO_DISTRIBUIDORA        float64
# CNPJ_DISTRIBUIDORA             object
# dtype: object

# %%
df2['DATA_LANCAMENTO_OBRA']=pd.to_datetime(df2['DATA_LANCAMENTO_OBRA'])
# Out:
# C:\Users\vitor\anaconda3.9\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '28/08/2025' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\vitor\anaconda3.9\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '21/08/2025' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\vitor\anaconda3.9\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '20/08/2025' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
df2['DATA_LANCAMENTO_OBRA'].value_counts()
# Out:
# 2015-03-12    19
# 2024-05-30    17
# 2018-07-06    16
# 2014-06-19    16
# 2024-11-28    16
#               ..
# 2020-01-09     1
# 2014-07-06     1
# 2020-06-08     1
# 2012-04-09     1
# 2015-08-29     1
# Name: DATA_LANCAMENTO_OBRA, Length: 1162, dtype: int64

# %%
df2.dtypes
# Out:
# DATA_LANCAMENTO_OBRA          datetime64[ns]
# TITULO_ORIGINAL                       object
# CPB_ROE                               object
# TIPO_OBRA                             object
# PAIS_OBRA                             object
# PUBLICO_TOTAL                          int64
# RENDA_TOTAL                           object
# RAZAO_SOCIAL_DISTRIBUIDORA            object
# REGISTRO_DISTRIBUIDORA               float64
# CNPJ_DISTRIBUIDORA                    object
# dtype: object

# %%
df2['DATA_LANCAMENTO_OBRA'].dt.year.value_counts()
# Out:
# 2015    498
# 2024    488
# 2016    482
# 2018    479
# 2017    477
# 2019    460
# 2023    442
# 2014    427
# 2013    401
# 2022    397
# 2025    343
# 2009    337
# 2011    335
# 2012    333
# 2021    309
# 2010    309
# 2020    198
# Name: DATA_LANCAMENTO_OBRA, dtype: int64

# %%
df2['DATA_LANCAMENTO_OBRA'].dt.year.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2[df2[PUBLICO_TOTAL]==df2[PUBLICO_TOTAL].max()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 df2[df2[PUBLICO_TOTAL]==df2[PUBLICO_TOTAL].max()]
#
# NameError: name 'PUBLICO_TOTAL' is not defined

# %%
df['RENDA_TOTAL'] = pd.to_numeric(df['RENDA_TOTAL'].str.replace(',', '.'), errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3.9\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3.9\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3.9\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RENDA_TOTAL'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df2['RENDA_TOTAL'].value_counts()
# Out:
# R$ 20,00            5
# R$ 70,00            5
# R$ 10,00            4
# R$ 60,00            4
# R$ 90,00            4
#                    ..
# R$ 24.425.970,79    1
# R$ 16.167.184,42    1
# R$ 15.163,13        1
# R$ 106.427,24       1
# R$ 141.070,93       1
# Name: RENDA_TOTAL, Length: 6664, dtype: int64

# %%
df2['RENDA_TOTAL'].value_counts.max()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 df2['RENDA_TOTAL'].value_counts.max()
#
# AttributeError: 'function' object has no attribute 'max'

# %%
df2[df2['RENDA_TOTAL']==df2['RENDA_TOTAL'].max()]
# Out:
#     DATA_LANCAMENTO_OBRA TITULO_ORIGINAL         CPB_ROE TIPO_OBRA PAIS_OBRA  \
# 596           2024-06-27     CASA IZABEL  B2300002900000    FICÇÃO    BRASIL
#
#      PUBLICO_TOTAL RENDA_TOTAL         RAZAO_SOCIAL_DISTRIBUIDORA  \
# 596             60   R$ 999,62  OLHAR DISTRIBUICAO DE FILMES LTDA
#
#      REGISTRO_DISTRIBUIDORA  CNPJ_DISTRIBUIDORA
# 596                 37242.0  28.083.221/0001-90

# %%
df2[df2['RENDA_TOTAL']==df2['RENDA_TOTAL'].max()]
# Out:
#     DATA_LANCAMENTO_OBRA TITULO_ORIGINAL         CPB_ROE TIPO_OBRA PAIS_OBRA  \
# 596           2024-06-27     CASA IZABEL  B2300002900000    FICÇÃO    BRASIL
#
#      PUBLICO_TOTAL RENDA_TOTAL         RAZAO_SOCIAL_DISTRIBUIDORA  \
# 596             60   R$ 999,62  OLHAR DISTRIBUICAO DE FILMES LTDA
#
#      REGISTRO_DISTRIBUIDORA  CNPJ_DISTRIBUIDORA
# 596                 37242.0  28.083.221/0001-90

# %%
df2[df2['RENDA_TOTAL']==df2['RENDA_TOTAL'].min()]
# Out:
#      DATA_LANCAMENTO_OBRA          TITULO_ORIGINAL         CPB_ROE  \
# 134            2025-05-15  CAIAM AS ROSAS BRANCAS!  B2500112300000
# 2548           2019-03-14      LAS HIJAS DEL FUEGO  E1900037000000
# 5005           2013-12-27            SÃO SILVESTRE  B1301963900000
#
#          TIPO_OBRA  PAIS_OBRA  PUBLICO_TOTAL RENDA_TOTAL  \
# 134         FICÇÃO  ARGENTINA              1     R$ 1,00
# 2548        FICÇÃO  ARGENTINA              1     R$ 1,00
# 5005  DOCUMENTÁRIO     BRASIL              1     R$ 1,00
#
#                     RAZAO_SOCIAL_DISTRIBUIDORA  REGISTRO_DISTRIBUIDORA  \
# 134   KOMPANHIA TEATRO MULTIMÍDIA DE SÃO PAULO                 57643.0
# 2548  KOMPANHIA TEATRO MULTIMÍDIA DE SÃO PAULO                 57643.0
# 5005  KOMPANHIA TEATRO MULTIMÍDIA DE SÃO PAULO                 57643.0
#
#       CNPJ_DISTRIBUIDORA
# 134   60.740.149/0001-39
# 2548  60.740.149/0001-39
# 5005  60.740.149/0001-39

# %%
df2[df2['PUBLICO_TOTAL']==df2['PUBLICO_TOTAL'].min()]
# Out:
#      DATA_LANCAMENTO_OBRA               TITULO_ORIGINAL         CPB_ROE  \
# 96             2025-05-06            AINDA NÃO É AMANHÃ  B2500126800000
# 134            2025-05-15       CAIAM AS ROSAS BRANCAS!  B2500112300000
# 713            2024-11-04        AS LINHAS DA MINHA MÃO  B2300145400000
# 1058           2023-07-20             MÁQUINA DO DESEJO  B2100381700000
# 2055           2020-08-10                    ZONA ÁRIDA  B2000259000000
# 2300           2019-02-10                PIPOCA MODERNA  B2400040800000
# 2548           2019-03-14           LAS HIJAS DEL FUEGO  E1900037000000
# 3838           2016-07-07                       JULIETA  E1600356700000
# 4645           2014-10-30  ATÉ QUE A SBÓRNIA NOS SEPARE  B1301874500000
# 5005           2013-12-27                 SÃO SILVESTRE  B1301963900000
# 5512           2012-07-09                 CARA OU COROA  B1201586300000
#
#          TIPO_OBRA  PAIS_OBRA  PUBLICO_TOTAL RENDA_TOTAL  \
# ...

# %%
df2[df2['PUBLICO_TOTAL']==df2['PUBLICO_TOTAL'].max()]
# Out:
#     DATA_LANCAMENTO_OBRA TITULO_ORIGINAL         CPB_ROE TIPO_OBRA  \
# 605           2024-06-20    INSIDE OUT 2  E2400179900000  ANIMAÇÃO
#
#           PAIS_OBRA  PUBLICO_TOTAL        RENDA_TOTAL  \
# 605  ESTADOS UNIDOS       22471950  R$ 444.445.640,62
#
#                  RAZAO_SOCIAL_DISTRIBUIDORA  REGISTRO_DISTRIBUIDORA  \
# 605  THE WALT DISNEY COMPANY (BRASIL) LTDA.                 18398.0
#
#      CNPJ_DISTRIBUIDORA
# 605  73.042.962/0001-87

# %%
df2.loc[[605,606,607,608]]
# Out:
#     DATA_LANCAMENTO_OBRA          TITULO_ORIGINAL         CPB_ROE TIPO_OBRA  \
# 605           2024-06-20             INSIDE OUT 2  E2400179900000  ANIMAÇÃO
# 606           2024-06-20               O ESTRANHO  B2400020300000    FICÇÃO
# 607           2024-06-20           THE BIKERIDERS  E2400070700000    FICÇÃO
# 608           2024-06-20  TO KALOKAIRI TIS KARMEN  E2400017100000    FICÇÃO
#
#           PAIS_OBRA  PUBLICO_TOTAL        RENDA_TOTAL  \
# 605  ESTADOS UNIDOS       22471950  R$ 444.445.640,62
# 606          FRANÇA            799        R$ 9.049,21
# 607  ESTADOS UNIDOS          29252      R$ 710.019,06
# 608          GRÉCIA            230        R$ 2.718,63
#
#                     RAZAO_SOCIAL_DISTRIBUIDORA  REGISTRO_DISTRIBUIDORA  \
# 605     THE WALT DISNEY COMPANY (BRASIL) LTDA.                 18398.0
# 606                        EMBAUBA FILMES LTDA                 23638.0
# 607                  WARNER BROS. (SOUTH) INC.                   265.0
# ...

# %%
df2.loc[df2['RAZAO_SOCIAL_DISTRIBUIDORA']=='THE WALT DISNEY COMPANY (BRASIL) LTDA.']
# Out:
#      DATA_LANCAMENTO_OBRA                  TITULO_ORIGINAL         CPB_ROE  \
# 3              2025-08-28                        THE ROSES  E2500319600000
# 28             2025-07-08                  FREAKIER FRIDAY  E2500278000000
# 45             2025-07-24  THE FANTASTIC FOUR: FIRST STEPS  E2500247600000
# 82             2025-06-19                             ELIO  E2500204800000
# 121            2025-05-22                    LILO & STITCH  E2500174800000
# ...                   ...                              ...             ...
# 6176           2010-03-09                        NOSSO LAR  B1001259400000
# 6387           2009-12-18                           AVATAR  E1402514700000
# 6405           2009-11-12          THE PRINCESS & THE FROG  E1402794800000
# 6495           2009-04-09                               UP  E1500587900000
# 6564           2009-11-06       HANNAH MONTANA - THE MOVIE  E1500530400000
#
#      TIPO_OBRA       PAIS_OBRA  PUBLICO_TOTAL        RENDA_TOTAL  \
# ...

# %%
df2.loc[df2['PUBLICO_TOTAL']>1000000]
# Out:
#      DATA_LANCAMENTO_OBRA                      TITULO_ORIGINAL  \
# 32             2025-07-08                              WEAPONS
# 45             2025-07-24      THE FANTASTIC FOUR: FIRST STEPS
# 59             2025-07-17                               SMURFS
# 64             2025-10-07                             SUPERMAN
# 70             2025-03-07              JURASSIC WORLD: REBIRTH
# ...                   ...                                  ...
# 6693           2009-01-23                      BEDTIME STORIES
# 6702           2009-01-16  THE CURIOUS CASE OF BENJAMIN BUTTON
# 6709           2009-09-01        THE DAY THE EARTH STOOD STILL
# 6712           2009-02-01                   SE EU FOSSE VOCÊ 2
# 6713           2009-01-01                                 BOLT
#
#              CPB_ROE TIPO_OBRA       PAIS_OBRA  PUBLICO_TOTAL  \
# 32    E2500283000000    FICÇÃO  ESTADOS UNIDOS        1003432
# 45    E2500247600000    FICÇÃO  ESTADOS UNIDOS        4010421
# ...

# %%
df2.loc[df2['RENDA_TOTAL']>'R$ 1.000.000,00']
# Out:
#      DATA_LANCAMENTO_OBRA     TITULO_ORIGINAL         CPB_ROE TIPO_OBRA  \
# 0              2025-08-28           AFTERBURN  E2500252400000    FICÇÃO
# 1              2025-08-28     CAUGHT STEALING  E2500247500000    FICÇÃO
# 2              2025-08-28       O ÚLTIMO AZUL  B2500299400000    FICÇÃO
# 3              2025-08-28           THE ROSES  E2500319600000    FICÇÃO
# 4              2025-08-21      BRING HER BACK  E2500097000000    FICÇÃO
# ...                   ...                 ...             ...       ...
# 6710           2009-04-01       THE STRANGERS  E1600633000000    FICÇÃO
# 6711           2009-02-01  SE EU FOSSE VOCÊ 2  B0800958700000    FICÇÃO
# 6712           2009-02-01  SE EU FOSSE VOCÊ 2  B0800958700000    FICÇÃO
# 6713           2009-01-01                BOLT  E1500346000000  ANIMAÇÃO
# 6714           2009-01-01   LA BELLE PERSONNE  E1600594000000    FICÇÃO
#
#            PAIS_OBRA  PUBLICO_TOTAL       RENDA_TOTAL  \
# ...

# %%
df2.loc[df2['PUBLICO_TOTAL']>22471940]
# Out:
#     DATA_LANCAMENTO_OBRA TITULO_ORIGINAL         CPB_ROE TIPO_OBRA  \
# 605           2024-06-20    INSIDE OUT 2  E2400179900000  ANIMAÇÃO
#
#           PAIS_OBRA  PUBLICO_TOTAL        RENDA_TOTAL  \
# 605  ESTADOS UNIDOS       22471950  R$ 444.445.640,62
#
#                  RAZAO_SOCIAL_DISTRIBUIDORA  REGISTRO_DISTRIBUIDORA  \
# 605  THE WALT DISNEY COMPANY (BRASIL) LTDA.                 18398.0
#
#      CNPJ_DISTRIBUIDORA
# 605  73.042.962/0001-87

# %%
df2.loc[[1105,2105,3105,4105,5105]]
# Out:
#      DATA_LANCAMENTO_OBRA   TITULO_ORIGINAL         CPB_ROE TIPO_OBRA  \
# 1105           2023-01-06  CORAZON ARDIENTE  E2100477300000    FICÇÃO
# 2105           2020-12-03        TECHNOBOSS  E1900533200000    FICÇÃO
# 3105           2018-11-01      DARKEST HOUR  E1700535000000    FICÇÃO
# 4105           2015-03-12       BEM CASADOS  B1500840400000    FICÇÃO
# 5105           2013-11-10   THIS IS THE END  E1500839500000    FICÇÃO
#
#            PAIS_OBRA  PUBLICO_TOTAL      RENDA_TOTAL  \
# 1105         ESPANHA           3172     R$ 51.040,50
# 2105        PORTUGAL            123      R$ 1.526,19
# 3105     REINO UNIDO         409014  R$ 8.322.315,18
# 4105          BRASIL         545829  R$ 6.940.418,06
# 5105  ESTADOS UNIDOS         159657  R$ 1.612.596,75
#
#                          RAZAO_SOCIAL_DISTRIBUIDORA  REGISTRO_DISTRIBUIDORA  \
# 1105               AM DE MORAIS PRODUCOES E EVENTOS                 51361.0
# ...

# %%
df2.loc[['Avengers']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 df2.loc[['Avengers']]
#
# File ~\anaconda3.9\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3.9\lib\site-packages\pandas\core\indexing.py:1191, in _LocIndexer._getitem_axis(self, key, axis)
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
#    1189         raise ValueError("Cannot index with multidimensional key")
# -> 1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
#    1194 if is_nested_tuple(key, labels):
#
# ...
